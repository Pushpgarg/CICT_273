# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report , accuracy_score
from sklearn.model_selection import train_test_split
import math
import csv

# %%
def pipeline(no_of_features , all_features , x_train , x_test , y_train , y_test , n_estimators = 100 , max_depth=None):
  features = all_features.copy()
  random.shuffle(features)

  selected_features = features[:no_of_features]
  x_train = x_train[selected_features]
  x_test = x_test[selected_features]

  classifier = RandomForestClassifier(n_estimators=n_estimators , max_depth = max_depth , random_state=42)
  classifier.fit(x_train,y_train)
  y_test_pred = classifier.predict(x_test)
  y_train_pred = classifier.predict(x_train)

  return accuracy_score(y_test,y_test_pred) , accuracy_score(y_train,y_train_pred) , selected_features

# %%
# filename = "smote_tomek_results/results_binary.csv"
# header = ['n_estimators', 'max_depth', 'no_of_features', 'train_accuracy', 'test_accuracy', 'selected_features']
# all_features = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']
# all_columns = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','target']

# x_train = pd.read_csv("smote_tomek_dataset/X_train_scaled_binary.csv")
# y_train = pd.read_csv("smote_tomek_dataset/y_train_binary.csv")
# x_test = pd.read_csv("smote_tomek_dataset/X_test_scaled_binary.csv") 
# y_test = pd.read_csv("smote_tomek_dataset/y_test_binary.csv")

# with open(filename, mode='w', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)
#     writer.writeheader()

# with open(filename, mode='a', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)

#     for j in range(1, 122, 10):
#         for k in range(1, 11):
#             for m in range(1, len(all_columns)):
#                 for i in range(20):
#                     test_acc, train_acc, selected_subset = pipeline(m, all_features, x_train , x_test , y_train , y_test , n_estimators=j, max_depth=k)
#                     writer.writerow({
#                         'n_estimators': j,
#                         'max_depth': k,
#                         'no_of_features': m,
#                         'train_accuracy': train_acc,
#                         'test_accuracy': test_acc,
#                         'selected_features': selected_subset
#                     })

# print("Results have been appended to", filename)

# %%
# filename = "smote_tomek_results/results_14_23.csv"
# header = ['n_estimators', 'max_depth', 'no_of_features', 'train_accuracy', 'test_accuracy', 'selected_features']
# all_features = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']
# all_columns = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','target']

# x_train = pd.read_csv("smote_tomek_dataset/X_train_scaled_14_23.csv")
# y_train = pd.read_csv("smote_tomek_dataset/y_train_14_23.csv")
# x_test = pd.read_csv("smote_tomek_dataset/X_test_scaled_14_23.csv") 
# y_test = pd.read_csv("smote_tomek_dataset/y_test_14_23.csv")

# with open(filename, mode='w', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)
#     writer.writeheader()

# with open(filename, mode='a', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)

#     for j in range(1, 11):
#         for k in range(1, 11):
#             for m in range(1, len(all_columns)):
#                 for i in range(20):
#                     test_acc, train_acc, selected_subset = pipeline(m, all_features, x_train , x_test , y_train , y_test , n_estimators=j, max_depth=k)
#                     writer.writerow({
#                         'n_estimators': j,
#                         'max_depth': k,
#                         'no_of_features': m,
#                         'train_accuracy': train_acc,
#                         'test_accuracy': test_acc,
#                         'selected_features': selected_subset
#                     })

# print("Results have been appended to", filename)

# %%
# filename = "smote_tomek_results/results_1_4.csv"
# header = ['n_estimators', 'max_depth', 'no_of_features', 'train_accuracy', 'test_accuracy', 'selected_features']
# all_features = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']
# all_columns = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','target']

# x_train = pd.read_csv("smote_tomek_dataset/X_train_scaled_1_4.csv")
# y_train = pd.read_csv("smote_tomek_dataset/y_train_1_4.csv")
# x_test = pd.read_csv("smote_tomek_dataset/X_test_scaled_1_4.csv") 
# y_test = pd.read_csv("smote_tomek_dataset/y_test_1_4.csv")

# with open(filename, mode='w', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)
#     writer.writeheader()

# with open(filename, mode='a', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)

#     for j in range(1, 11):
#         for k in range(1, 11):
#             for m in range(1, len(all_columns)):
#                 for i in range(20):
#                     test_acc, train_acc, selected_subset = pipeline(m, all_features, x_train , x_test , y_train , y_test , n_estimators=j, max_depth=k)
#                     writer.writerow({
#                         'n_estimators': j,
#                         'max_depth': k,
#                         'no_of_features': m,
#                         'train_accuracy': train_acc,
#                         'test_accuracy': test_acc,
#                         'selected_features': selected_subset
#                     })

# print("Results have been appended to", filename)

# %%
# filename = "smote_tomek_results/results_2_3.csv"
# header = ['n_estimators', 'max_depth', 'no_of_features', 'train_accuracy', 'test_accuracy', 'selected_features']
# all_features = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']
# all_columns = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','target']

# x_train = pd.read_csv("smote_tomek_dataset/X_train_scaled_2_3.csv")
# y_train = pd.read_csv("smote_tomek_dataset/y_train_2_3.csv")
# x_test = pd.read_csv("smote_tomek_dataset/X_test_scaled_2_3.csv") 
# y_test = pd.read_csv("smote_tomek_dataset/y_test_2_3.csv")

# with open(filename, mode='w', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)
#     writer.writeheader()

# with open(filename, mode='a', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)

#     for j in range(1, 10):
#         for k in range(1, 11):
#             for m in range(1, len(all_columns)):
#                 for i in range(20):
#                     test_acc, train_acc, selected_subset = pipeline(m, all_features, x_train , x_test , y_train , y_test , n_estimators=j, max_depth=k)
#                     writer.writerow({
#                         'n_estimators': j,
#                         'max_depth': k,
#                         'no_of_features': m,
#                         'train_accuracy': train_acc,
#                         'test_accuracy': test_acc,
#                         'selected_features': selected_subset
#                     })

# print("Results have been appended to", filename)

# %%
import pandas as pd
end = "2_3"
# Read the CSV file
tryi = pd.read_csv(f'smote_tomek_results/results_{end}.csv')

# Filter rows where the difference between test and train accuracy is less than 0.05 (no underfitting)
filtered_df = tryi[(tryi['test_accuracy'] - tryi['train_accuracy']) < 0.05 ]

# From these, select the row(s) with the maximum test accuracy
max_test_acc_row = filtered_df[filtered_df['test_accuracy'] == filtered_df['test_accuracy'].max()]
# max_test_acc_row = filtered_df[filtered_df['test_accuracy'] > 0.9]

max_test_acc_row
# Out:
#       n_estimators  max_depth  no_of_features  train_accuracy  test_accuracy  \
# 9170             4          6               4           0.841       0.857143
#
#                               selected_features
# 9170  ['exang', 'restecg', 'trestbps', 'slope']

# %%
# # Best selected features from previous results
# selected_features = ['exang', 'restecg', 'trestbps', 'slope']
# # Read data
# x_train = pd.read_csv(f"smote_tomek_dataset/X_train_scaled_{end}.csv")[selected_features]
# y_train = pd.read_csv(f"smote_tomek_dataset/y_train_{end}.csv")
# x_test = pd.read_csv(f"smote_tomek_dataset/X_test_scaled_{end}.csv")[selected_features]
# y_test = pd.read_csv(f"smote_tomek_dataset/y_test_{end}.csv")

# # Convert y from DataFrame to Series (to fix warning)
# y_train = y_train.values.ravel()
# y_test = y_test.values.ravel()

# # Train and evaluate
# classifier = RandomForestClassifier(n_estimators=4, max_depth=6, random_state=42)
# classifier.fit(x_train, y_train)

# y_test_pred = classifier.predict(x_test)
# y_train_pred = classifier.predict(x_train)

# print("testing")
# print(classification_report(y_test, y_test_pred,digits=6))
# print("training")
# print(classification_report(y_train, y_train_pred , digits=6))
# Out:
# testing
#               precision    recall  f1-score   support
#
#            2   1.000000  0.714286  0.833333         7
#            3   0.777778  1.000000  0.875000         7
#
#     accuracy                       0.857143        14
#    macro avg   0.888889  0.857143  0.854167        14
# weighted avg   0.888889  0.857143  0.854167        14
#
# training
#               precision    recall  f1-score   support
#
#            2   0.863539  0.810000  0.835913      1000
#            3   0.821092  0.872000  0.845781      1000
#
#     accuracy                       0.841000      2000
#    macro avg   0.842316  0.841000  0.840847      2000
# weighted avg   0.842316  0.841000  0.840847      2000

# %%
# import joblib

# # Save the trained model
# joblib.dump(classifier, f'smote_tomek_models/model_{end}.pkl')

# print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
smote_tomek_models = {
    'binary': load('smote_tomek_models/model_binary.pkl'),
    '14_23': load('smote_tomek_models/model_14_23.pkl'),
    '1_4': load('smote_tomek_models/model_1_4.pkl'),
    '2_3': load('smote_tomek_models/model_2_3.pkl'),
}

smote_tomek_scalers = {
    'binary': load('smote_tomek_scaler/scaler_binary.pkl'),
    '14_23': load('smote_tomek_scaler/scaler_14_23.pkl'),
    '1_4': load('smote_tomek_scaler/scaler_1_4.pkl'),
    '2_3': load('smote_tomek_scaler/scaler_2_3.pkl'),
}

smote_tomek_features_dict = {
    'binary': ['thalach', 'sex', 'fbs', 'exang', 'restecg', 'oldpeak'],
    '1_4': ['trestbps', 'cp', 'ca', 'oldpeak', 'chol', 'slope', 'thal', 'exang'],
    '2_3': ['exang', 'restecg', 'trestbps', 'slope'],
    '14_23': ['chol', 'cp', 'exang', 'thal', 'age', 'oldpeak', 'fbs', 'slope', 'sex', 'ca', 'trestbps', 'thalach'],
}

# %%
'''
binary
testing
              precision    recall  f1-score   support

           0   0.909091  0.937500  0.923077        32
           1   0.925926  0.892857  0.909091        28

    accuracy                       0.916667        60
   macro avg   0.917508  0.915179  0.916084        60
weighted avg   0.916947  0.916667  0.916550        60

training
              precision    recall  f1-score   support

           0   0.866401  0.871615  0.869000       997
           1   0.870838  0.865597  0.868209       997

    accuracy                       0.868606      1994
   macro avg   0.868619  0.868606  0.868605      1994
weighted avg   0.868619  0.868606  0.868605      1994

<===================================================================>

14_23  
testing
              precision    recall  f1-score   support

           1   0.923077  0.857143  0.888889        14
           2   0.866667  0.928571  0.896552        14

    accuracy                       0.892857        28
   macro avg   0.894872  0.892857  0.892720        28
weighted avg   0.894872  0.892857  0.892720        28

training
              precision    recall  f1-score   support

           1   0.960526  0.949000  0.954728      1000
           2   0.949605  0.961000  0.955268      1000

    accuracy                       0.955000      2000
   macro avg   0.955066  0.955000  0.954998      2000
weighted avg   0.955066  0.955000  0.954998      2000

<===================================================================>

1_4
testing
              precision    recall  f1-score   support

           1   1.000000  1.000000  1.000000        11
           4   1.000000  1.000000  1.000000         3

    accuracy                       1.000000        14
   macro avg   1.000000  1.000000  1.000000        14
weighted avg   1.000000  1.000000  1.000000        14

training
              precision    recall  f1-score   support

           1   1.000000  0.992000  0.995984      1000
           4   0.992063  1.000000  0.996016      1000

    accuracy                       0.996000      2000
   macro avg   0.996032  0.996000  0.996000      2000
weighted avg   0.996032  0.996000  0.996000      2000

<===================================================================>

2_3
testing
              precision    recall  f1-score   support

           2   1.000000  0.714286  0.833333         7
           3   0.777778  1.000000  0.875000         7

    accuracy                       0.857143        14
   macro avg   0.888889  0.857143  0.854167        14
weighted avg   0.888889  0.857143  0.854167        14

training
              precision    recall  f1-score   support

           2   0.863539  0.810000  0.835913      1000
           3   0.821092  0.872000  0.845781      1000

    accuracy                       0.841000      2000
   macro avg   0.842316  0.841000  0.840847      2000
weighted avg   0.842316  0.841000  0.840847      2000

'''
