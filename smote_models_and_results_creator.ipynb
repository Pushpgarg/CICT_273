# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report , accuracy_score
from sklearn.model_selection import train_test_split
import math
import csv
from imblearn.over_sampling import SMOTE

# %%
# def pipeline(no_of_features , all_features , x_train , x_test , y_train , y_test , n_estimators = 100 , max_depth=None):
#   features = all_features.copy()
#   random.shuffle(features)

#   selected_features = features[:no_of_features]
#   x_train = x_train[selected_features]
#   x_test = x_test[selected_features]

#   classifier = RandomForestClassifier(n_estimators=n_estimators , max_depth = max_depth , random_state=42)
#   classifier.fit(x_train,y_train)
#   y_test_pred = classifier.predict(x_test)
#   y_train_pred = classifier.predict(x_train)

#   return accuracy_score(y_test,y_test_pred) , accuracy_score(y_train,y_train_pred) , selected_features

# %%
# filename = "smote_results/results_binary.csv"
# header = ['n_estimators', 'max_depth', 'no_of_features', 'train_accuracy', 'test_accuracy', 'selected_features']
# all_features = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']
# all_columns = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','target']

# x_train = pd.read_csv("datasets/X_train_scaled_smote_binary.csv")
# y_train = pd.read_csv("datasets/y_train_smote_binary.csv")
# x_test = pd.read_csv("datasets/X_test_scaled_smote_binary.csv") 
# y_test = pd.read_csv("datasets/y_test_smote_binary.csv")

# with open(filename, mode='w', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)
#     writer.writeheader()

# with open(filename, mode='a', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)

#     for j in range(1, 122, 10):
#         for k in range(1, 11):
#             for m in range(1, len(all_columns)):
#                 for i in range(20):
#                     test_acc, train_acc, selected_subset = pipeline(m, all_features, x_train , x_test , y_train , y_test , n_estimators=j, max_depth=k)
#                     writer.writerow({
#                         'n_estimators': j,
#                         'max_depth': k,
#                         'no_of_features': m,
#                         'train_accuracy': train_acc,
#                         'test_accuracy': test_acc,
#                         'selected_features': selected_subset
#                     })

# print("Results have been appended to", filename)

# %%
# filename = "smote_results/results_14_23.csv"
# header = ['n_estimators', 'max_depth', 'no_of_features', 'train_accuracy', 'test_accuracy', 'selected_features']
# all_features = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']
# all_columns = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','target']

# x_train = pd.read_csv("datasets/X_train_scaled_smote_14_23.csv")
# y_train = pd.read_csv("datasets/y_train_smote_14_23.csv")
# x_test = pd.read_csv("datasets/X_test_scaled_smote_14_23.csv") 
# y_test = pd.read_csv("datasets/y_test_smote_14_23.csv")

# with open(filename, mode='w', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)
#     writer.writeheader()

# with open(filename, mode='a', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)

#     for j in range(1, 11):
#         for k in range(1, 11):
#             for m in range(1, len(all_columns)):
#                 for i in range(20):
#                     test_acc, train_acc, selected_subset = pipeline(m, all_features, x_train , x_test , y_train , y_test , n_estimators=j, max_depth=k)
#                     writer.writerow({
#                         'n_estimators': j,
#                         'max_depth': k,
#                         'no_of_features': m,
#                         'train_accuracy': train_acc,
#                         'test_accuracy': test_acc,
#                         'selected_features': selected_subset
#                     })

# print("Results have been appended to", filename)

# %%
# filename = "smote_results/results_1_4.csv"
# header = ['n_estimators', 'max_depth', 'no_of_features', 'train_accuracy', 'test_accuracy', 'selected_features']
# all_features = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']
# all_columns = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','target']

# x_train = pd.read_csv("datasets/X_train_scaled_smote_1_4.csv")
# y_train = pd.read_csv("datasets/y_train_smote_1_4.csv")
# x_test = pd.read_csv("datasets/X_test_scaled_smote_1_4.csv") 
# y_test = pd.read_csv("datasets/y_test_smote_1_4.csv")

# with open(filename, mode='w', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)
#     writer.writeheader()

# with open(filename, mode='a', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)

#     for j in range(1, 11):
#         for k in range(1, 11):
#             for m in range(1, len(all_columns)):
#                 for i in range(20):
#                     test_acc, train_acc, selected_subset = pipeline(m, all_features, x_train , x_test , y_train , y_test , n_estimators=j, max_depth=k)
#                     writer.writerow({
#                         'n_estimators': j,
#                         'max_depth': k,
#                         'no_of_features': m,
#                         'train_accuracy': train_acc,
#                         'test_accuracy': test_acc,
#                         'selected_features': selected_subset
#                     })

# print("Results have been appended to", filename)

# %%
# filename = "smote_results/results_2_3.csv"
# header = ['n_estimators', 'max_depth', 'no_of_features', 'train_accuracy', 'test_accuracy', 'selected_features']
# all_features = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']
# all_columns = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','target']

# x_train = pd.read_csv("datasets/X_train_scaled_smote_2_3.csv")
# y_train = pd.read_csv("datasets/y_train_smote_2_3.csv")
# x_test = pd.read_csv("datasets/X_test_scaled_smote_2_3.csv") 
# y_test = pd.read_csv("datasets/y_test_smote_2_3.csv")

# with open(filename, mode='w', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)
#     writer.writeheader()

# with open(filename, mode='a', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=header)

#     for j in range(1, 10):
#         for k in range(1, 11):
#             for m in range(1, len(all_columns)):
#                 for i in range(20):
#                     test_acc, train_acc, selected_subset = pipeline(m, all_features, x_train , x_test , y_train , y_test , n_estimators=j, max_depth=k)
#                     writer.writerow({
#                         'n_estimators': j,
#                         'max_depth': k,
#                         'no_of_features': m,
#                         'train_accuracy': train_acc,
#                         'test_accuracy': test_acc,
#                         'selected_features': selected_subset
#                     })

# print("Results have been appended to", filename)

# %% [markdown]
# ### saving models

# %%
# # Best selected features from previous results
# selected_features = ['oldpeak', 'thal', 'cp', 'fbs', 'chol', 'age', 'ca', 'sex', 'slope', 'trestbps', 'restecg']

# # Read data
# x_train = pd.read_csv("smote_dataset/X_train_scaled_smote_2_3.csv")[selected_features]
# y_train = pd.read_csv("smote_dataset/y_train_smote_2_3.csv")
# x_test = pd.read_csv("smote_dataset/X_test_scaled_smote_2_3.csv")[selected_features]
# y_test = pd.read_csv("smote_dataset/y_test_smote_2_3.csv")

# # Convert y from DataFrame to Series (to fix warning)
# y_train = y_train.values.ravel()
# y_test = y_test.values.ravel()

# # Train and evaluate
# classifier = RandomForestClassifier(n_estimators=1, max_depth=5, random_state=42)
# classifier.fit(x_train, y_train)

# y_test_pred = classifier.predict(x_test)
# y_train_pred = classifier.predict(x_train)

# print(classification_report(y_test, y_test_pred))
# print("<======================================================================>")
# print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.86      0.86      0.86         7
#            3       0.86      0.86      0.86         7
#
#     accuracy                           0.86        14
#    macro avg       0.86      0.86      0.86        14
# weighted avg       0.86      0.86      0.86        14
#
# <======================================================================>
#               precision    recall  f1-score   support
#
#            2       0.82      0.95      0.88      1000
#            3       0.94      0.79      0.86      1000
#
#     accuracy                           0.87      2000
#    macro avg       0.88      0.87      0.87      2000
# weighted avg       0.88      0.87      0.87      2000

# %%
# import joblib

# # Save the trained model
# joblib.dump(classifier, 'smote_models/model_2_3.pkl')

# print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
'''
for binary classification 
class name = 0 , 1
n_estimators = 121
max_depth = 6
no_of_features = 8
features = ['fbs', 'slope', 'ca', 'restecg', 'exang', 'sex', 'thalach', 'chol']

               precision    recall  f1-score   support

           0       0.89      0.97      0.93        32
           1       0.96      0.86      0.91        28

    accuracy                           0.92        60
   macro avg       0.92      0.91      0.92        60
weighted avg       0.92      0.92      0.92        60

<======================================================================>
               precision    recall  f1-score   support

           0       0.91      0.90      0.91      1000
           1       0.90      0.91      0.91      1000

    accuracy                           0.91      2000
   macro avg       0.91      0.91      0.91      2000
weighted avg       0.91      0.91      0.91      2000

_______________________________________________________________________________________________

for 14 vs 23 classification
class name = 1 (for 14) , 2 (for 23)
n_estimators = 7
max_depth = 5
no_of_features = 7
features = ['ca', 'cp', 'slope', 'fbs', 'age', 'restecg', 'trestbps']
              precision    recall  f1-score   support

           1       0.87      0.93      0.90        14
           2       0.92      0.86      0.89        14

    accuracy                           0.89        28
   macro avg       0.89      0.89      0.89        28
weighted avg       0.89      0.89      0.89        28

<======================================================================>
              precision    recall  f1-score   support

           1       0.83      0.87      0.85      1000
           2       0.87      0.83      0.85      1000

    accuracy                           0.85      2000
   macro avg       0.85      0.85      0.85      2000
weighted avg       0.85      0.85      0.85      2000
___________________________________________________________________________


for 1 vs 4 classification
class name = 1 , 4
n_estimators = 5
max_depth = 10
no_of_features = 13
features = ['chol', 'fbs', 'thal', 'restecg', 'ca', 'sex', 'exang', 'age', 'oldpeak', 'trestbps', 'thalach', 'cp', 'slope']

                precision    recall  f1-score   support

           1       1.00      1.00      1.00        11
           4       1.00      1.00      1.00         3

    accuracy                           1.00        14
   macro avg       1.00      1.00      1.00        14
weighted avg       1.00      1.00      1.00        14

<======================================================================>
                precision    recall  f1-score   support

           1       1.00      1.00      1.00      1000
           4       1.00      1.00      1.00      1000

    accuracy                           1.00      2000
   macro avg       1.00      1.00      1.00      2000
weighted avg       1.00      1.00      1.00      2000

___________________________________________________________________________


for 2 vs 3 classification
class name = 2,3
n_estimators = 1
max_depth = 5
no_of_features = 11
features = ['oldpeak', 'thal', 'cp', 'fbs', 'chol', 'age', 'ca', 'sex', 'slope', 'trestbps', 'restecg']

               precision    recall  f1-score   support

           2       0.86      0.86      0.86         7
           3       0.86      0.86      0.86         7

    accuracy                           0.86        14
   macro avg       0.86      0.86      0.86        14
weighted avg       0.86      0.86      0.86        14

<======================================================================>
               precision    recall  f1-score   support

           2       0.82      0.95      0.88      1000
           3       0.94      0.79      0.86      1000

    accuracy                           0.87      2000
   macro avg       0.88      0.87      0.87      2000
weighted avg       0.88      0.87      0.87      2000
'''
